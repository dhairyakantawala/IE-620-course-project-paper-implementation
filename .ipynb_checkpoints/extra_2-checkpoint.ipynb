# %%
from helper_functions import files_list, get_months, get_normalised_data

# %%
months = get_months()

# %%
features = [
    'ret_1m',
    'ret_3m',
    'mom_12m',
    'vol_3m',
    'vol_6m',
    'vol_z',
    'vol_trend',
    'ey_z',
    'bm_z',
    'mc_z',
    'rev_6m',
    'mom_vol_adj',
    'value_mom',
    'liquidity_adj_mom'
]

# %%
for file in files_list:
    get_normalised_data(file).to_csv('normalised_data/'+file)
